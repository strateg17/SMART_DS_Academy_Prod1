# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/a8/eb/a48f25c967526b66d5f1fa7a984594f0bf0a5afafa94a8c4dbc317744620/scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 1.4MB/s
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/c6/e8/c216b9b60cbba4642d3ca1bae7a53daa0c24426f662e0e3ce3dc7f6caeaa/threadpoolctl-2.2.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.2 threadpoolctl-2.2.0

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
import numpy as np
import pandas as pd
import datetime as dt
import fbprophet
from dateutil.relativedelta import relativedelta
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import ParameterGrid
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.linear_model import LinearRegression

# %%
pd.options.display.max_rows=100

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
products = pd.read_csv('/content/drive/MyDrive/project1/products.csv')
products
# Out:
#                              product_id  ... product_width_cm
# 0      1e9e8ef04dbcff4541ed26657ea517e5  ...             14.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f  ...             20.0
# 2      96bd76ec8810374ed1b65e291975717f  ...             15.0
# 3      cef67bcfe19066a932b7673e239eb23d  ...             26.0
# 4      9dc1a7de274444849c219cff195d0b71  ...             13.0
# ...                                 ...  ...              ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0  ...             40.0
# 32947  bf4538d88321d0fd4412a93c974510e6  ...             16.0
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c  ...             27.0
# 32949  83808703fc0706a22e264b9d75f04a2e  ...             20.0
# 32950  106392145fca363410d287a815be6de4  ...              7.0
#
# [32951 rows x 9 columns]

# %%
del products['product_name_lenght'], products['product_description_lenght'], products['product_photos_qty']
products
# Out:
#                              product_id  ... product_width_cm
# 0      1e9e8ef04dbcff4541ed26657ea517e5  ...             14.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f  ...             20.0
# 2      96bd76ec8810374ed1b65e291975717f  ...             15.0
# 3      cef67bcfe19066a932b7673e239eb23d  ...             26.0
# 4      9dc1a7de274444849c219cff195d0b71  ...             13.0
# ...                                 ...  ...              ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0  ...             40.0
# 32947  bf4538d88321d0fd4412a93c974510e6  ...             16.0
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c  ...             27.0
# 32949  83808703fc0706a22e264b9d75f04a2e  ...             20.0
# 32950  106392145fca363410d287a815be6de4  ...              7.0
#
# [32951 rows x 6 columns]

# %%
products['product_volume_cm3'] = products.product_length_cm*products.product_height_cm*products.product_width_cm
products
# Out:
#                              product_id  ... product_volume_cm3
# 0      1e9e8ef04dbcff4541ed26657ea517e5  ...             2240.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f  ...            10800.0
# 2      96bd76ec8810374ed1b65e291975717f  ...             2430.0
# 3      cef67bcfe19066a932b7673e239eb23d  ...             2704.0
# 4      9dc1a7de274444849c219cff195d0b71  ...             4420.0
# ...                                 ...  ...                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0  ...            64000.0
# 32947  bf4538d88321d0fd4412a93c974510e6  ...             4864.0
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c  ...             5103.0
# 32949  83808703fc0706a22e264b9d75f04a2e  ...             8060.0
# 32950  106392145fca363410d287a815be6de4  ...              168.0
#
# [32951 rows x 7 columns]

# %%
#количество уникальных продуктов
products.product_id.nunique()
# Out:
# 32951

# %%
products.isna().sum()
# Out:
# product_id                 0
# product_category_name    610
# product_weight_g           2
# product_length_cm          2
# product_height_cm          2
# product_width_cm           2
# product_volume_cm3         2
# dtype: int64

# %% [markdown]
# Проверим, стоит ли товары с отсутствующей категорией (Other) разбивать еще на несколько категорий, сравнив среднее и среднеквадратическое отклонение в этой категории с данными характеристиками других категорий

# %%
products.groupby(['product_category_name']).agg({'product_volume_cm3':'mean'}).sort_values(by='product_volume_cm3')
# Out:
#                                                 product_volume_cm3
# product_category_name
# dvds_blu_ray                                           1746.854167
# telefonia                                              1865.841270
# livros_importados                                      1935.387097
# livros_tecnicos                                        2758.991870
# relogios_presentes                                     3470.398044
# livros_interesse_geral                                 3900.046296
# fashion_bolsas_e_acessorios                            4480.634865
# fashion_underwear_e_moda_praia                         4584.132075
# audio                                                  4970.172414
# telefonia_fixa                                         5018.681034
# perfumaria                                             5136.218894
# flores                                                 6334.857143
# informatica_acessorios                                 6483.912142
# alimentos                                              6634.121951
# musica                                                 6727.481481
# fashion_esporte                                        6789.894737
# artes_e_artesanato                                     6895.947368
# consoles_games                                         6898.905363
# cine_foto                                              6952.392857
# pc_gamer                                               7074.666667
# fashion_roupa_feminina                                 7165.259259
# tablets_impressao_imagem                               7182.222222
# construcao_ferramentas_ferramentas                     7357.666667
# construcao_ferramentas_seguranca                       7472.054945
# fashion_roupa_infanto_juvenil                          7590.200000
# alimentos_bebidas                                      7947.163462
# eletronicos                                            7962.506770
# fraldas_higiene                                        8468.416667
# fashion_calcados                                       8478.208092
# fashion_roupa_masculina                                8798.421053
# seguros_e_servicos                                    10233.500000
# beleza_saude                                          10468.159165
# artes                                                 10668.490909
# bebidas                                               11217.802469
# market_place                                          12973.480769
# cds_dvds_musicais                                     13125.000000
# construcao_ferramentas_jardim                         13399.670455
# eletrodomesticos                                      13451.751351
# artigos_de_natal                                      13947.046154
# esporte_lazer                                         14725.348797
# construcao_ferramentas_construcao                     15455.385000
# papelaria                                             16240.032980
# automotivo                                            16603.585263
# artigos_de_festas                                     16942.730769
# cama_mesa_banho                                       18594.577088
# ferramentas_jardim                                    18615.406375
# portateis_cozinha_e_preparadores_de_alimentos         18872.700000
# construcao_ferramentas_iluminacao                     18897.256410
# brinquedos                                            19625.812899
# casa_construcao                                       20800.235556
# casa_conforto_2                                       20938.000000
# utilidades_domesticas                                 21904.167880
# moveis_decoracao                                      22481.225442
# sinalizacao_e_seguranca                               22583.795699
# pet_shop                                              22965.066759
# cool_stuff                                            23246.484157
# portateis_casa_forno_e_cafe                           23911.612903
# instrumentos_musicais                                 25089.020761
# eletroportateis                                       26913.238095
# climatizacao                                          27910.532258
# casa_conforto                                         28148.729730
# la_cuisine                                            30483.400000
# bebes                                                 30835.576253
# malas_acessorios                                      32950.335244
# industria_comercio_e_negocios                         37372.308824
# agro_industria_e_comercio                             37604.229730
# pcs                                                   44635.166667
# moveis_quarto                                         51038.844444
# moveis_sala                                           54486.128205
# eletrodomesticos_2                                    55476.311111
# moveis_cozinha_area_de_servico_jantar_e_jardim        69406.095745
# moveis_escritorio                                     75468.469256
# moveis_colchao_e_estofado                             77244.300000

# %%
products.groupby(['product_category_name']).agg({'product_volume_cm3':'std'}).sort_values(by='product_volume_cm3')
# Out:
#                                                 product_volume_cm3
# product_category_name
# livros_importados                                      1206.736803
# pc_gamer                                               1620.278165
# telefonia                                              2023.848886
# dvds_blu_ray                                           2896.124152
# livros_tecnicos                                        3084.661858
# livros_interesse_geral                                 3503.460753
# fashion_roupa_infanto_juvenil                          3800.294752
# relogios_presentes                                     4020.254201
# flores                                                 4789.929803
# fraldas_higiene                                        5088.245339
# audio                                                  5428.558282
# seguros_e_servicos                                     5574.122756
# fashion_calcados                                       5611.237739
# fashion_underwear_e_moda_praia                         5762.227898
# construcao_ferramentas_ferramentas                     6184.007359
# perfumaria                                             6224.344249
# fashion_roupa_masculina                                6996.038783
# construcao_ferramentas_seguranca                       7042.161990
# alimentos                                              7455.868176
# alimentos_bebidas                                      7685.279816
# cine_foto                                              7889.054022
# telefonia_fixa                                         7906.497140
# bebidas                                                8554.800768
# artes_e_artesanato                                     8834.623513
# portateis_cozinha_e_preparadores_de_alimentos          8931.985359
# informatica_acessorios                                 9371.486512
# tablets_impressao_imagem                              10512.738389
# musica                                                11363.109553
# fashion_bolsas_e_acessorios                           11616.965656
# artes                                                 13011.043809
# fashion_roupa_feminina                                13821.354319
# fashion_esporte                                       14999.035057
# casa_conforto_2                                       15514.825813
# market_place                                          16444.240896
# construcao_ferramentas_jardim                         16779.781781
# consoles_games                                        17148.732805
# papelaria                                             17565.093625
# eletronicos                                           17588.889628
# artigos_de_natal                                      18351.007932
# la_cuisine                                            20249.899644
# casa_conforto                                         21017.382173
# cama_mesa_banho                                       22303.275186
# esporte_lazer                                         23232.455958
# construcao_ferramentas_construcao                     23255.290883
# eletrodomesticos                                      23611.734303
# brinquedos                                            23633.345698
# automotivo                                            23975.007196
# construcao_ferramentas_iluminacao                     26249.929693
# casa_construcao                                       26501.689823
# eletroportateis                                       27715.089060
# climatizacao                                          27715.777304
# ferramentas_jardim                                    28365.864744
# utilidades_domesticas                                 28876.883298
# pet_shop                                              29052.755646
# beleza_saude                                          29360.095370
# portateis_casa_forno_e_cafe                           30495.570348
# artigos_de_festas                                     30738.278522
# moveis_decoracao                                      31403.266934
# cool_stuff                                            31561.708104
# malas_acessorios                                      33427.839743
# pcs                                                   33840.191285
# instrumentos_musicais                                 34745.007199
# moveis_escritorio                                     36044.325529
# moveis_quarto                                         36624.440795
# sinalizacao_e_seguranca                               38101.785763
# bebes                                                 39820.561328
# industria_comercio_e_negocios                         41345.544629
# agro_industria_e_comercio                             44137.030604
# eletrodomesticos_2                                    44857.913239
# moveis_cozinha_area_de_servico_jantar_e_jardim        58946.567239
# moveis_sala                                           69171.645627
# moveis_colchao_e_estofado                             85641.111693
# cds_dvds_musicais                                              NaN

# %%
products.fillna({'product_category_name':'Other'}, inplace=True)

# %%
order_items = pd.read_csv('/content/drive/MyDrive/project1/order_items.csv', parse_dates=[4])
order_items
# Out:
#                                 order_id  order_item_id  ...   price freight_value
# 0       00010242fe8c5a6d1ba2dd792cb16214              1  ...   58.90         13.29
# 1       00018f77f2f0320c557190d7a144bdd3              1  ...  239.90         19.93
# 2       000229ec398224ef6ca0657da4fc703e              1  ...  199.00         17.87
# 3       00024acbcdf0a6daa1e931b038114c75              1  ...   12.99         12.79
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1  ...  199.90         18.14
# ...                                  ...            ...  ...     ...           ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1  ...  299.99         43.41
# 112646  fffcd46ef2263f404302a634eb57f7eb              1  ...  350.00         36.53
# 112647  fffce4705a9662cd70adb13d4a31832d              1  ...   99.90         16.95
# 112648  fffe18544ffabc95dfada21779c9644f              1  ...   55.99          8.72
# 112649  fffe41c64501cc87c801fd61db3f6244              1  ...   43.00         12.79
#
# [112650 rows x 7 columns]

# %%
order_items.product_id.nunique()
# Out:
# 32951

# %%
orders = pd.read_csv('/content/drive/MyDrive/project1/orders.csv', parse_dates=['order_approved_at'])
orders
# Out:
#                                order_id  ... order_estimated_delivery_date
# 0      e481f51cbdc54678b7cc49136f2d6af7  ...           2017-10-18 00:00:00
# 1      53cdb2fc8bc7dce0b6741e2150273451  ...           2018-08-13 00:00:00
# 2      47770eb9100c2d0c44946d9cf07ec65d  ...           2018-09-04 00:00:00
# 3      949d5b44dbf5de918fe9c16f97b45f8a  ...           2017-12-15 00:00:00
# 4      ad21c59c0840e6cb83a9ceb5573f8159  ...           2018-02-26 00:00:00
# ...                                 ...  ...                           ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  ...           2017-03-28 00:00:00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  ...           2018-03-02 00:00:00
# 99438  83c1379a015df1e13d02aae0204711ab  ...           2017-09-27 00:00:00
# 99439  11c177c8e97725db2631073c19f07b62  ...           2018-02-15 00:00:00
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  ...           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
full_data = pd.merge(order_items, orders.loc[:, ['order_id', 'order_delivered_customer_date']], on='order_id', how='left')
full_data
# Out:
#                                 order_id  ...  order_delivered_customer_date
# 0       00010242fe8c5a6d1ba2dd792cb16214  ...            2017-09-20 23:43:48
# 1       00018f77f2f0320c557190d7a144bdd3  ...            2017-05-12 16:04:24
# 2       000229ec398224ef6ca0657da4fc703e  ...            2018-01-22 13:19:16
# 3       00024acbcdf0a6daa1e931b038114c75  ...            2018-08-14 13:32:39
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ...            2017-03-01 16:42:31
# ...                                  ...  ...                            ...
# 112645  fffc94f6ce00a00581880bf54a75a037  ...            2018-05-10 22:56:40
# 112646  fffcd46ef2263f404302a634eb57f7eb  ...            2018-07-23 20:31:55
# 112647  fffce4705a9662cd70adb13d4a31832d  ...            2017-10-28 12:22:22
# 112648  fffe18544ffabc95dfada21779c9644f  ...            2017-08-16 21:59:40
# 112649  fffe41c64501cc87c801fd61db3f6244  ...            2018-06-14 17:56:26
#
# [112650 rows x 8 columns]

# %%
full_data = pd.merge(full_data, products, on='product_id', how='left')
full_data
# Out:
#                                 order_id  ...  product_volume_cm3
# 0       00010242fe8c5a6d1ba2dd792cb16214  ...              3528.0
# 1       00018f77f2f0320c557190d7a144bdd3  ...             60000.0
# 2       000229ec398224ef6ca0657da4fc703e  ...             14157.0
# 3       00024acbcdf0a6daa1e931b038114c75  ...              2400.0
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ...             42000.0
# ...                                  ...  ...                 ...
# 112645  fffc94f6ce00a00581880bf54a75a037  ...             53400.0
# 112646  fffcd46ef2263f404302a634eb57f7eb  ...             44460.0
# 112647  fffce4705a9662cd70adb13d4a31832d  ...              9576.0
# 112648  fffe18544ffabc95dfada21779c9644f  ...              8000.0
# 112649  fffe41c64501cc87c801fd61db3f6244  ...              1710.0
#
# [112650 rows x 14 columns]

# %%
full_data.product_category_name.nunique()
# Out:
# 74

# %%
full_data
# Out:
#                                 order_id  ...  product_volume_cm3
# 0       00010242fe8c5a6d1ba2dd792cb16214  ...              3528.0
# 1       00018f77f2f0320c557190d7a144bdd3  ...             60000.0
# 2       000229ec398224ef6ca0657da4fc703e  ...             14157.0
# 3       00024acbcdf0a6daa1e931b038114c75  ...              2400.0
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ...             42000.0
# ...                                  ...  ...                 ...
# 112645  fffc94f6ce00a00581880bf54a75a037  ...             53400.0
# 112646  fffcd46ef2263f404302a634eb57f7eb  ...             44460.0
# 112647  fffce4705a9662cd70adb13d4a31832d  ...              9576.0
# 112648  fffe18544ffabc95dfada21779c9644f  ...              8000.0
# 112649  fffe41c64501cc87c801fd61db3f6244  ...              1710.0
#
# [112650 rows x 14 columns]

# %%
full_data['Index'] = range(len(full_data))

# %%
full_data
# Out:
#                                 order_id  ...   Index
# 0       00010242fe8c5a6d1ba2dd792cb16214  ...       0
# 1       00018f77f2f0320c557190d7a144bdd3  ...       1
# 2       000229ec398224ef6ca0657da4fc703e  ...       2
# 3       00024acbcdf0a6daa1e931b038114c75  ...       3
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ...       4
# ...                                  ...  ...     ...
# 112645  fffc94f6ce00a00581880bf54a75a037  ...  112645
# 112646  fffcd46ef2263f404302a634eb57f7eb  ...  112646
# 112647  fffce4705a9662cd70adb13d4a31832d  ...  112647
# 112648  fffe18544ffabc95dfada21779c9644f  ...  112648
# 112649  fffe41c64501cc87c801fd61db3f6244  ...  112649
#
# [112650 rows x 15 columns]

# %% [markdown]
# Посчитаем количество продаж конкретных товаров

# %%
product_sells.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9345610150>]],
#       dtype=object)

# %% [markdown]
# Основная масса товаров продается меньше 50 раз

# %%
translation = pd.read_csv('/content/drive/MyDrive/project1/product_category_name_translation.csv')

# %%
translation
# Out:
#                              product_category_name            product_category_name_english
# 0                                     beleza_saude                            health_beauty
# 1                           informatica_acessorios                    computers_accessories
# 2                                       automotivo                                     auto
# 3                                  cama_mesa_banho                           bed_bath_table
# 4                                 moveis_decoracao                          furniture_decor
# 5                                    esporte_lazer                           sports_leisure
# 6                                       perfumaria                                perfumery
# 7                            utilidades_domesticas                               housewares
# 8                                        telefonia                                telephony
# 9                               relogios_presentes                            watches_gifts
# 10                               alimentos_bebidas                               food_drink
# 11                                           bebes                                     baby
# 12                                       papelaria                               stationery
# 13                        tablets_impressao_imagem                   tablets_printing_image
# 14                                      brinquedos                                     toys
# 15                                  telefonia_fixa                          fixed_telephony
# 16                              ferramentas_jardim                             garden_tools
# 17                     fashion_bolsas_e_acessorios                 fashion_bags_accessories
# 18                                 eletroportateis                         small_appliances
# 19                                  consoles_games                           consoles_games
# 20                                           audio                                    audio
# 21                                fashion_calcados                            fashion_shoes
# 22                                      cool_stuff                               cool_stuff
# 23                                malas_acessorios                      luggage_accessories
# 24                                    climatizacao                         air_conditioning
# 25               construcao_ferramentas_construcao          construction_tools_construction
# 26  moveis_cozinha_area_de_servico_jantar_e_jardim  kitchen_dining_laundry_garden_furniture
# 27                   construcao_ferramentas_jardim                 costruction_tools_garden
# 28                         fashion_roupa_masculina                    fashion_male_clothing
# 29                                        pet_shop                                 pet_shop
# 30                               moveis_escritorio                         office_furniture
# 31                                    market_place                             market_place
# 32                                     eletronicos                              electronics
# 33                                eletrodomesticos                          home_appliances
# 34                               artigos_de_festas                           party_supplies
# 35                                   casa_conforto                             home_confort
# 36              construcao_ferramentas_ferramentas                  costruction_tools_tools
# 37                       agro_industria_e_comercio               agro_industry_and_commerce
# 38                       moveis_colchao_e_estofado        furniture_mattress_and_upholstery
# 39                                 livros_tecnicos                          books_technical
# 40                                 casa_construcao                        home_construction
# 41                           instrumentos_musicais                      musical_instruments
# 42                                     moveis_sala                    furniture_living_room
# 43               construcao_ferramentas_iluminacao                construction_tools_lights
# 44                   industria_comercio_e_negocios           industry_commerce_and_business
# 45                                       alimentos                                     food
# 46                                           artes                                      art
# 47                                   moveis_quarto                        furniture_bedroom
# 48                          livros_interesse_geral                   books_general_interest
# 49                construcao_ferramentas_seguranca                construction_tools_safety
# 50                  fashion_underwear_e_moda_praia                  fashion_underwear_beach
# 51                                 fashion_esporte                            fashion_sport
# 52                         sinalizacao_e_seguranca                   signaling_and_security
# 53                                             pcs                                computers
# 54                                artigos_de_natal                       christmas_supplies
# 55                          fashion_roupa_feminina                   fashio_female_clothing
# 56                              eletrodomesticos_2                        home_appliances_2
# 57                               livros_importados                           books_imported
# 58                                         bebidas                                   drinks
# 59                                       cine_foto                               cine_photo
# 60                                      la_cuisine                               la_cuisine
# 61                                          musica                                    music
# 62                                 casa_conforto_2                           home_comfort_2
# 63                     portateis_casa_forno_e_cafe    small_appliances_home_oven_and_coffee
# 64                               cds_dvds_musicais                        cds_dvds_musicals
# 65                                    dvds_blu_ray                             dvds_blu_ray
# 66                                          flores                                  flowers
# 67                              artes_e_artesanato                    arts_and_craftmanship
# 68                                 fraldas_higiene                      diapers_and_hygiene
# 69                   fashion_roupa_infanto_juvenil                fashion_childrens_clothes
# 70                              seguros_e_servicos                    security_and_services

# %%
full_data  = pd.merge(full_data, translation, on='product_category_name', how='left')

# %%
full_data
# Out:
#                                 order_id  ...  product_category_name_english
# 0       00010242fe8c5a6d1ba2dd792cb16214  ...                     cool_stuff
# 1       00018f77f2f0320c557190d7a144bdd3  ...                       pet_shop
# 2       000229ec398224ef6ca0657da4fc703e  ...                furniture_decor
# 3       00024acbcdf0a6daa1e931b038114c75  ...                      perfumery
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ...                   garden_tools
# ...                                  ...  ...                            ...
# 112645  fffc94f6ce00a00581880bf54a75a037  ...                     housewares
# 112646  fffcd46ef2263f404302a634eb57f7eb  ...          computers_accessories
# 112647  fffce4705a9662cd70adb13d4a31832d  ...                 sports_leisure
# 112648  fffe18544ffabc95dfada21779c9644f  ...          computers_accessories
# 112649  fffe41c64501cc87c801fd61db3f6244  ...                 bed_bath_table
#
# [112650 rows x 16 columns]

# %%
full_data = full_data.loc[:, ['product_id', 'seller_id', 'product_category_name_english','order_delivered_customer_date']]
full_data = full_data.sort_values(by='order_delivered_customer_date')
full_data
# Out:
#                               product_id  ... order_delivered_customer_date
# 23966   43bb8825dd6838251606e5e4130cfff4  ...           2016-10-11 13:46:32
# 23965   43bb8825dd6838251606e5e4130cfff4  ...           2016-10-11 13:46:32
# 49383   35084deab9603bbb6035bb8638b1df89  ...           2016-10-11 14:46:49
# 92532   c3b8f6be3507bb05fd83797f81f679bc  ...           2016-10-13 03:10:34
# 64210   f07ef9dd6e2d9a366ff30a25e210be70  ...           2016-10-13 07:45:48
# ...                                  ...  ...                           ...
# 112211  0c7536abc1af51a81fa806097dfe3597  ...                           NaN
# 112256  b27653c33039497c46ceba21db46a43c  ...                           NaN
# 112340  6803077179d24889430188e03fafd31a  ...                           NaN
# 112384  53d2c16e7356d124bb2a3f64ca920754  ...                           NaN
# 112421  4228bf901c8db392cbffcbc1f14a13e2  ...                           NaN
#
# [112650 rows x 4 columns]

# %%
full_data.fillna({'product_category_name_english':'Other'}, inplace=True)

# %%
full_data.isna().sum()
# Out:
# product_id                          0
# seller_id                           0
# product_category_name_english       0
# order_delivered_customer_date    2454
# dtype: int64

# %%
full_data.dropna(inplace=True)

# %% [markdown]
# Отберем товары, которые продавались больше 1 раза

# %%
not_new_prod_id = full_data.groupby('product_id', as_index=False).agg('count')
not_new_prod_id = not_new_prod_id[not_new_prod_id.order_delivered_customer_date > 1]
not_new_prod_id = not_new_prod_id.product_id
not_new_prod_id
# Out:
# 3        000b8f95fcb9e0096488278317764d19
# 6        00126f27c813603687e6ce486d909d01
# 7        001795ec6f1b187d37335e1c4704762e
# 9        001b72dfd63e9833e8c02742adf472e3
# 11       00210e41887c2a8ef9f791ebc780cc36
#                        ...
# 32203    ffedbd68fa6f44e788ff6c2db8094715
# 32204    ffef256879dbadcab7e77950f4f4a195
# 32205    fff0a542c3c62682f23305214eaeaa24
# 32209    fff6177642830a9a94a0f2cba5e476d1
# 32212    fffdb2d0ec8d6a61f0a0a0db3f25b441
# Name: product_id, Length: 14498, dtype: object

# %%
full_data = full_data[full_data.product_id.isin(not_new_prod_id)]
full_data
# Out:
#                               product_id  ... order_delivered_customer_date
# 23966   43bb8825dd6838251606e5e4130cfff4  ...           2016-10-11 13:46:32
# 23965   43bb8825dd6838251606e5e4130cfff4  ...           2016-10-11 13:46:32
# 92532   c3b8f6be3507bb05fd83797f81f679bc  ...           2016-10-13 03:10:34
# 64210   f07ef9dd6e2d9a366ff30a25e210be70  ...           2016-10-13 07:45:48
# 36169   b6f134ff2933bb0ee1f36e2865f21a91  ...           2016-10-13 15:45:44
# ...                                  ...  ...                           ...
# 106581  d04857e7b4b708ee8b8b9921163edba3  ...           2018-09-21 23:46:29
# 54987   9fe172fa8e662ca8572cf12abf8bce23  ...           2018-09-25 00:47:25
# 71337   ddceb6eef6af67e9fbbd4c148dbe5fd9  ...           2018-09-27 02:24:33
# 78512   78efe838c04bbc568be034082200ac20  ...           2018-10-02 00:18:50
# 55605   b7a812ed1b86b3b00e566dc29ba7ec7c  ...           2018-10-17 13:22:46
#
# [92480 rows x 4 columns]

# %%
full_data['order_delivered_customer_date'] = pd.to_datetime(full_data['order_delivered_customer_date'])

# %%
full_data.order_delivered_customer_date = full_data.order_delivered_customer_date.dt.date
full_data = full_data.rename(columns={'order_delivered_customer_date': 'date'})

# %%
prod_id_sells = full_data.groupby(['product_category_name_english', 'date']).agg({'date':'count'})
prod_id_sells = prod_id_sells.rename({'date':'sells_val'}, axis='columns')
prod_id_sells.reset_index(level='date', inplace = True)
prod_id_sells.reset_index(inplace=True)
prod_id_sells
# Out:
#       product_category_name_english        date  sells_val
# 0                             Other  2016-10-22          1
# 1                             Other  2016-10-28          1
# 2                             Other  2017-01-25          1
# 3                             Other  2017-01-30          1
# 4                             Other  2017-02-02          2
# ...                             ...         ...        ...
# 15289                 watches_gifts  2018-08-31          3
# 15290                 watches_gifts  2018-09-01          1
# 15291                 watches_gifts  2018-09-03          1
# 15292                 watches_gifts  2018-09-13          1
# 15293                 watches_gifts  2018-09-14          1
#
# [15294 rows x 3 columns]

# %% [markdown]
# Заполним месяца, в которых не было продаж товара, нулями

# %%
df = prod_id_sells.copy()
df['date'] = pd.to_datetime(df['date'])
df.index = df['date']
del df['date']
df_interpol = df.groupby(['product_category_name_english']).resample('D').mean()
df_interpol['sells_val'] = df_interpol['sells_val'].fillna(0)

# %%
df_interpol = df_interpol.reset_index()

# %%
del df_interpol['date']
series = df_interpol.groupby(['product_category_name_english'])['sells_val'].apply(list).to_dict()

# %% [markdown]
# Отеберем товары, которые продавались больше 2 месяцев, для того, чтобы ипользовать последний месяц в качестве тест-выборки

# %%
# Создадим словарь для продуктов, которые продавались меньше 60 дней
series_unpopular_product = dict()

# %%
for k in series.copy():
    if len(series[k]) < 60:
        series_unpopular_product[k] = series[k]
        del series[k]

# %%
len(series)
# Out:
# 70

# %% [markdown]
# ### Словарь с необходимыми временными рядами

# %%
len(series_unpopular_product)
# Out:
# 1

# %% [markdown]
# ## Прогнозирование

# %% [markdown]
# Выберем конкретный SKU для прогнозирования

# %%
SKU = input('Введите SKU для прогнозирования: ')
# Out:
# Введите SKU для прогнозирования: bed_bath_table

# %%
SKU_sells = prod_id_sells[prod_id_sells.product_category_name_english == SKU]
SKU_sells
# Out:
#      product_category_name_english        date  sells_val
# 1863                bed_bath_table  2016-10-17          3
# 1864                bed_bath_table  2016-10-27          1
# 1865                bed_bath_table  2017-01-17          1
# 1866                bed_bath_table  2017-01-20          2
# 1867                bed_bath_table  2017-01-23          2
# ...                            ...         ...        ...
# 2389                bed_bath_table  2018-08-31          1
# 2390                bed_bath_table  2018-09-03          1
# 2391                bed_bath_table  2018-09-06          1
# 2392                bed_bath_table  2018-09-11          1
# 2393                bed_bath_table  2018-10-17          1
#
# [531 rows x 3 columns]

# %%
df_interpol.describe(include='all')
# Out:
#        product_category_name_english     sells_val
# count                          38854  38854.000000
# unique                            71           NaN
# top                   bed_bath_table           NaN
# freq                             731           NaN
# mean                             NaN      2.380193
# std                              NaN      5.520763
# min                              NaN      0.000000
# 25%                              NaN      0.000000
# 50%                              NaN      0.000000
# 75%                              NaN      2.000000
# max                              NaN     78.000000

# %%
if SKU in series_unpopular_product:
    
    unpop_dates_list = []
    for i in range(1, 22): # Создаем последовательность дат на 21 день с момента последней продажи продукта
        unpop_dates_list.append(last_sale + relativedelta(days=+i))
        
    lm = LinearRegression()
    lm.fit(np.arange(1,len(series_unpopular_product[SKU]) + 1).reshape(-1, 1), series_unpopular_product[SKU])
    lm_predictions = lm.predict(np.arange(len(series_unpopular_product[SKU]) + 1, len(series_unpopular_product[SKU]) + 1 + 21).reshape(-1, 1))
    lm_predictions = np.where(lm_predictions >= 0, lm_predictions, 0)
    predictions = pd.DataFrame({'Date':unpop_dates_list, 'Prediction':lm_predictions})
    predictions = predictions[7:].reset_index(drop=True) # Отбросим первую неделю, поскольку заказчику был необходим прогноз по истечению недели со дня последней продажи
    print(predictions)
    exit()

# %% [markdown]
# Создадим помесячную последовательноть дат для SKU

# %%
dates_list = []
for i in range(len(series[SKU])):
    dates_list.append(first_sale + relativedelta(days=+i))

# %%
SKU_df = pd.DataFrame({'date':dates_list, 'sells_val':series[SKU]})
SKU_df.columns = ['ds', 'y']
SKU_df
# Out:
#              ds    y
# 0    2017-01-21  3.0
# 1    2017-01-22  0.0
# 2    2017-01-23  0.0
# 3    2017-01-24  0.0
# 4    2017-01-25  0.0
# ..          ...  ...
# 726  2019-01-17  0.0
# 727  2019-01-18  0.0
# 728  2019-01-19  0.0
# 729  2019-01-20  0.0
# 730  2019-01-21  1.0
#
# [731 rows x 2 columns]

# %% [markdown]
# Отберем последний месяц продаж товара в качестве тестовой выборки

# %%
SKU_train_df = SKU_df.iloc[:-30,]
SKU_test_df = SKU_df.iloc[-30:,]

# %% [markdown]
# ### Prophet

# %%
params_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
}
grid = ParameterGrid(params_grid)

# %%
errors = np.ndarray([])
for p in grid:
    m = fbprophet.Prophet(**p, daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False, uncertainty_samples=False)
    m.fit(SKU_train_df)
    predictions = m.predict(SKU_test_df.drop(['y'], axis=1))
    predictions = predictions.loc[:,['ds', 'yhat']]
    predictions.yhat = predictions.yhat.where(predictions.yhat>=0, 0)
    errors = np.append(errors, mean_absolute_percentage_error(SKU_test_df.y, predictions.yhat))
# Out:
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.

# %%
models_MSE = dict()
p = grid[errors.argmin()]
fb_model = fbprophet.Prophet(**p, daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False, uncertainty_samples=False)
fb_model.fit(SKU_train_df)
predictions = fb_model.predict(SKU_test_df.drop(['y'], axis=1))
predictions = predictions.loc[:,['ds', 'yhat']]
predictions.yhat = predictions.yhat.where(predictions.yhat>=0, 0)
models_MSE['fb_model'] = mean_absolute_percentage_error(SKU_test_df.y, predictions.yhat)
# Out:
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.

# %% [markdown]
# ### Экспоненциальное сглаживание

# %%
train = SKU_train_df.set_index('ds')
train.index = pd.to_datetime(train.index)
train = train.asfreq('d')
exp_sm_model = ExponentialSmoothing(train)
exp_sm_predictions = exp_sm_model.fit().forecast(30)
models_MSE['exp_sm'] = mean_absolute_percentage_error(SKU_test_df.y, exp_sm_predictions)

# %% [markdown]
# ### Наивная модель

# %%
naive_predictions = np.ones(len(SKU_test_df))*SKU_train_df.y.mean()
models_MSE['naive_model'] = mean_absolute_percentage_error(SKU_test_df.y, naive_predictions)

# %%
models_MSE = pd.DataFrame.from_dict(models_MSE, orient='index', columns=['MAPE'])
models_MSE = models_MSE.sort_values(by='MAPE')

# %% [markdown]
# Сравнение моделей по метрике MAE

# %%
models_MSE
# Out:
#                      MAPE
# exp_sm       2.262150e+16
# naive_model  5.827204e+16
# fb_model     1.108604e+17

# %% [markdown]
# Построение окончательного прогноза с помощью найлучшей модели на полных данных

# %%
if models_MSE.iloc[0,:].name == 'fb_model':
    print('Making predictions with Prophet model')
    fb_model = fbprophet.Prophet(**p, daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False, uncertainty_samples=False)
    fb_model.fit(SKU_df)
    future = fb_model.make_future_dataframe(periods=21, include_history=False)
    predictions = fb_model.predict(future)
    predictions.yhat = predictions.yhat.where(predictions.yhat>=0, 0)
    predictions = predictions.loc[:,['ds', 'yhat']]
    predictions = predictions[7:].reset_index(drop=True) # Отбросим первую неделю, поскольку заказчику был необходим прогноз по истечению недели со дня последней продажи
    predictions.columns = ['Date', 'Prediction']
    
elif models_MSE.iloc[0,:].name == 'exp_sm':
    print('Making predictions with Exponential Smoothing model')
    train = SKU_df.set_index('ds')
    train.index = pd.to_datetime(train.index)
    train = train.asfreq('d')
    exp_sm_model = ExponentialSmoothing(train)
    exp_sm_predictions = exp_sm_model.fit().forecast(21)
    
    exp_dates_list = []
    for i in range(1, 22): # Создаем последовательность дат на 21 день с момента последней продажи продукта
        exp_dates_list.append(last_sale + relativedelta(days=+i))
    
    predictions = pd.DataFrame({'Date':exp_dates_list, 'Prediction':exp_sm_predictions})
    predictions = predictions[7:].reset_index(drop=True) # Отбросим первую неделю, поскольку заказчику был необходим прогноз по истечению недели со дня последней продажи
    
elif models_MSE.iloc[0,:].name == 'naive_model':
    print('Making predictions with Naive model')
    naive_predictions = np.ones(21)*SKU_df.y.mean()
    
    naive_dates_list = []
    for i in range(1, 22): # Создаем последовательность дат на 21 день с момента последней продажи продукта
        naive_dates_list.append(last_sale + relativedelta(days=+i))
        
    predictions = pd.DataFrame({'Date':naive_dates_list, 'Prediction':naive_predictions})
    predictions = predictions[7:].reset_index(drop=True) # Отбросим первую неделю, поскольку заказчику был необходим прогноз по истечению недели со дня последней продажи
# Out:
# Making predictions with Exponential Smoothing model

# %% [markdown]
# ### Полученный прогноз

# %%
predictions
# Out:
#           Date  Prediction
# 0   2017-02-01    0.351895
# 1   2017-02-02    0.351895
# 2   2017-02-03    0.351895
# 3   2017-02-04    0.351895
# 4   2017-02-05    0.351895
# 5   2017-02-06    0.351895
# 6   2017-02-07    0.351895
# 7   2017-02-08    0.351895
# 8   2017-02-09    0.351895
# 9   2017-02-10    0.351895
# 10  2017-02-11    0.351895
# 11  2017-02-12    0.351895
# 12  2017-02-13    0.351895
# 13  2017-02-14    0.351895
